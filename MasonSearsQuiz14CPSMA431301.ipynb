# %% [markdown]
# <a href="https://colab.research.google.com/github/masonsears/-Data-Processing-Visualization-CPSMA-4313-01-projects/blob/Projects/MasonSearsQuiz14CPSMA431301.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pdfplumber

# %%
import pdfplumber

pdf = pdfplumber.open("sample-tables.pdf")

table = pdf.pages[2].extract_table(table_settings = {})

table
# Out:
# [['Rainfall (inches)', 'Americas', 'Asia', 'Europe', 'Africa'],
#  ['Average', '133', '244', '155', '166'],
#  ['24 hour high', '27', '28', '29', '20'],
#  ['12 hour high', '11', '12', '13', '16']]
