# %% [markdown]
# <a href="https://colab.research.google.com/github/masonsears/-Data-Processing-Visualization-CPSMA-4313-01-projects/blob/Projects/MasonSearsProjectEvaluateRecordCPSMA_4313_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mason Sears
# #  Data Processing Visualization (CPSMA-4313-01)
# # Instructor: Dr. Nicholas Jacob
# # GameStop Sales Compared to Steam Sales

# %% [markdown]
# # Introduction
# GameStop used to be the titan of videogame venders especialy in 2007 to 2016, selling consoles, video games, and accessories. However, today, with the popularity of digital downloads, they have made a steady decline in sales. Today, everything is digital, Xbox, Playstation and Steam have made a steady climb to the top, Steam being the most. successful of the three, reaching to about 10 billion sales in 2024 alone.

# %% [markdown]
# #What is the reason for this change?
# Back when videogames required the use of a physical disk, there was no reason to have a digital market, besides shipping games that weren't in stock, it was reasonable to go to Gamestope, or other stores that were very important at the time. Every gamer had shelves of their videogames and took up quite a lot of space. Today, people rarely buy phyical game copies anymore, as digital downloads are much more space-efficient and make switching between games completely seamless, without requiring the user to eject the disk and swap it out. This makes owning physical disks unpopular to most.copies

# %% [markdown]
# ![Screenshot 2026-03-07 200201.png](data:image/png;base64,...)

# %% [markdown]
# #Description
# The graph shows the yearly revenue for GameStop from 2001 to 2025, the original graphic is interactive which shows the specific revenue per year in billions. The graph shows a steam incline from 2005 to 2007, the revenue would average out at about 8-9 billion dollars until 2017, and made a gradual decline. The rise in revenue around 2020-2021 is due to a trend in which many people bought significant amounts of the company's stock. This event happened because their stock started to rise back towards its former glory, and people using the 'RobinHood' app decided to hop onto the trend as a form of support for the "underdog" against larger businesses at the time. According to this graph, to this graph it did not last for long, as revenue resumed its downward descent during 2022.

# %% [markdown]
# #Graphical excellence
# This graph is decent as it very plainly states its purpose. However, the graph cuts out a portion of the bottom numbers, which makes the company seem less well-off than it actually is. The graph is better on the website, as it has an interactive element that cannot be recreated in a picture. Having the actual revenue shown for each year would make it easier to read. The graph also stops after 2024, making ia little dated. I see very little bias in the graph; however, the scale for the graph is a little misleading.

# %% [markdown]
# #How the graph helped the article
# This graph was the center of the article, as it merely explained what the graph meant and how it was calculated. Under the graph, and how it was calculated. Under the graph it showed another graph showing the percentage of change in the graph, which does help to further explain it.

# %% [markdown]
# ![Screenshot 2026-03-07 210924.png](data:image/png;base64,...)

# %% [markdown]
# #Description
# This graph shows the revenue for Xbox from 2015 to 2025. As shown,h shows the revenue for Xbox from 2015 to 2025. As shown, the revenue fairly steadily increases with a small decrease in 2023 at about 15 billion. There was a 4 billion dollar jump from 2020 to 2021, likely due to the newer xbox one x/s coming out that year. Revenue again jumps exponentially in 2024 and 2025, likely due to many triple-A titles coming out those years, titles coming out those years such as Call of Duty 6, Forza 5, and other games that were very popular at the time.

# %% [markdown]
# #Graphical Excellence
# The graph is very simple and very efficiently shows the data that I needed to know. The graph does not show 2026 yet because 2025 is the latest full data that they know. The color used in the graph is also significant in a stylistic sense, because it is the logo's color.

# %% [markdown]
# #How the visualization helped the article
# The article is discusing how Xbox has the highest revenue this year despite having a 25% decrease in hardware sales. The graph doesn't show this however, because it only shows the revenue without any explanation how the lack of hardware sells hurt profits. Due to this being the only graphic in the article it doesn't help the author as much as it could have if they had divided the revenue into groups.

# %% [markdown]
# ![Screenshot 2026-03-07 200620.png](data:image/png;base64,...)

# %% [markdown]
# #Description
# This graph shows the revenue of Steam from 2018 to 2024. The graph shows a slow but steady increase in revenue from 2020 to 2022, followed by a larger increase in 2023 and 2024, likely due to the newly released Steam branded hand held consol. This shows that the yearly revenue is smaller than that of Xbox but more than that of GameStop. This is likely because until recently, Steam only sold digital titles, while not selling any physical products, which limits the amount of profit they can make.

# %% [markdown]
# #Graphical excellence
# This graph avoids distortion of the data by having proportional data. The data is excelently presented with the amount of revenue by year shown. However, the data lacks significant data points because of how small the time frame shown is. This graph is also slightly outdated because the most recent year is 2024.

# %% [markdown]
# #

# %% [markdown]
# #How the visualization helped the article
# This article doesn't only talk about sales and profit, it also discusses how many users are active, top-grossing games, and several other statistics that do a great job at showing information for the company. This graphic specifically shows how successful Steam has been in recent years.

# %% [markdown]
# #Similarities
# All of these graphs show the yearly revenue of each company. Each of the graphs shows a very simple explanation of the data without using flash graphics to attract attention.

# %% [markdown]
# #Differences
# While each graph discussed the companies in question and their reviews, they are all slightly different. The graph showing GameStop revenue shows a slightly pessimistic bias against GameStop, while the others just show the information plainly. The graph showing Xbox revenue is made by Xbox and shows the information with a histogram and has color to make the graphic look more interesting. The Steam graph is lacking in information due to it only going from 2018 to 2024; it shows the data without distortion and very plainly without fancy colors or graphics.

# %% [markdown]
# #Conclusion
# In conclusion, as a gamer myself, I care about what companies I buy from. As many I was a big fan of GameStop and frequently purchased from them. However, they. However, as the information shows, the world is changing to a digital age and we must move on.

# %% [markdown]
# #Refernces
#
#
# *   https://companiesmarketcap.com/gamestop/revenue/
# *   https://www.demandsage.com/steam-statistics/
# *   https://www.cato.org/cato-journal/fall-2021/gamestop-episode-what-happened-what-does-it-mean#game-stop-and-robinhood-in-early-2021
# *   https://www.tweaktown.com/news/106738/xbox-delivers-record-23-45-billion-annual-revenue-hardware-drops-25/index.html
